# %% [markdown]
# <a href="https://colab.research.google.com/github/Ademola409/Geospatial_data_science/blob/main/pothole.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd '/content/drive/MyDrive/potholeDetection'
# Out:
# /content/drive/MyDrive/potholeDetection

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.2-11-g529aafd Python-3.7.13 torch-1.12.1+cu113 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 37.1/107.7 GB disk)

# %%
# !pwd
# Out:
# /content/drive/MyDrive/potholeDetection

# %%
cd ..
# Out:
# /content/drive/MyDrive

# %%
from zipfile import ZipFile
file_name='train_data.zip'
with ZipFile(file_name, 'r') as zip:
  print('Extracting of the file now...')
  zip.extractall()
  print('Done')
# Out:
# Extracting of th file now...
# Done

# %%
cd potholeDetection/
# Out:
# /content/drive/MyDrive/potholeDetection

# %%
cd yolov5/
# Out:
# /content/drive/MyDrive/potholeDetection/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 20 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 2 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.2-11-g529aafd Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp5/weights/last.pt --img 640 --conf 0.35 --source ../potholevideo.mp4
# Out:
# detect: weights=['runs/train/exp5/weights/last.pt'], source=../potholevideo.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-11-g529aafd Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/1361) /content/drive/MyDrive/potholeDetection/potholevideo.mp4: 384x640 Done. (0.012s)
# video 1/1 (2/1361) /content/drive/MyDrive/potholeDetection/potholevideo.mp4: 384x640 Done. (0.009s)
# video 1/1 (3/1361) /content/drive/MyDrive/potholeDetection/potholevideo.mp4: 384x640 Done. (0.008s)
# ...
